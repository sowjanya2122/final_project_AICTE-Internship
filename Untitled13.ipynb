# %% [markdown]
# <a href="https://colab.research.google.com/github/sowjanya2122/project-internship/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# step 1

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
import joblib

# %%
import os

# %% [markdown]
# Step 2: Load Dataset

# %%
excel_file = '/content/SupplyChainEmissionFactorsforUSIndustriesCommodities(2015_Summary_Industry).csv'  # Replace with actual path
years = range(2010, 2017)

# df = pd.read_excel(r"path_data.xlsx")

# %%
years[0]
# Out:
# 2010

# %%
df_1 = pd.read_csv(excel_file)
df_1.head()
# Out:
#   Industry Code                              Industry Name       Substance  \
# 0         111CA                                      Farms  carbon dioxide
# 1         111CA                                      Farms         methane
# 2         111CA                                      Farms   nitrous oxide
# 3         111CA                                      Farms      other GHGs
# 4         113FF  Forestry, fishing, and related activities  carbon dioxide
#
#                                 Unit  \
# 0       kg/2018 USD, purchaser price
# 1       kg/2018 USD, purchaser price
# 2       kg/2018 USD, purchaser price
# 3  kg CO2e/2018 USD, purchaser price
# 4       kg/2018 USD, purchaser price
#
#    Supply Chain Emission Factors without Margins  \
# 0  Supply Chain Emission Factors without Margins
# 1                                          0.023
# 2                                          0.002
# 3                                          0.004
# 4                                          0.184
#
#    Margins of Supply Chain Emission Factors  \
# 0                                     0.041
# 1                                     0.000
# 2                                     0.000
# 3                                     0.000
# 4                                     0.017
#
#    Supply Chain Emission Factors with Margins  Unnamed: 7  \
# 0                                       0.465         NaN
# 1                                       0.023         NaN
# 2                                       0.002         NaN
# 3                                       0.004         NaN
# 4                                       0.201         NaN
#
#    DQ ReliabilityScore of Factors without Margins  \
# 0                                               4
# 1                                               3
# 2                                               4
# 3                                               3
# 4                                               4
#
#    DQ TemporalCorrelation of Factors without Margins  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    DQ GeographicalCorrelation of Factors without Margins  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    DQ TechnologicalCorrelation of Factors without Margins  \
# 0                                                  4
# 1                                                  1
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    DQ DataCollection of Factors without Margins
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 13 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Industry Code                                           264 non-null    object
#  1   Industry Name                                           264 non-null    object
#  2   Substance                                               264 non-null    object
#  3   Unit                                                    264 non-null    object
#  4   Supply Chain Emission Factors without Margins           264 non-null    object
#  5   Margins of Supply Chain Emission Factors                264 non-null    float64
#  6   Supply Chain Emission Factors with Margins              264 non-null    float64
#  7   Unnamed: 7                                              0 non-null      float64
#  8   DQ ReliabilityScore of Factors without Margins          264 non-null    int64
#  9   DQ TemporalCorrelation of Factors without Margins       264 non-null    int64
#  10  DQ GeographicalCorrelation of Factors without Margins   264 non-null    int64
#  11  DQ TechnologicalCorrelation of Factors without Margins  264 non-null    int64
#  12  DQ DataCollection of Factors without Margins            264 non-null    int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 26.9+ KB

# %%
df_1.isnull().sum()
# Out:
# Industry Code                                               0
# Industry Name                                               0
# Substance                                                   0
# Unit                                                        0
# Supply Chain Emission Factors without Margins               0
# Margins of Supply Chain Emission Factors                    0
# Supply Chain Emission Factors with Margins                  0
# Unnamed: 7                                                264
# DQ ReliabilityScore of Factors without Margins              0
# DQ TemporalCorrelation of Factors without Margins           0
# DQ GeographicalCorrelation of Factors without Margins       0
# DQ TechnologicalCorrelation of Factors without Margins      0
# DQ DataCollection of Factors without Margins                0
# dtype: int64

# %%
df_2 = pd.read_csv(excel_file)
df_2.head()
# Out:
#   Industry Code                              Industry Name       Substance  \
# 0         111CA                                      Farms  carbon dioxide
# 1         111CA                                      Farms         methane
# 2         111CA                                      Farms   nitrous oxide
# 3         111CA                                      Farms      other GHGs
# 4         113FF  Forestry, fishing, and related activities  carbon dioxide
#
#                                 Unit  \
# 0       kg/2018 USD, purchaser price
# 1       kg/2018 USD, purchaser price
# 2       kg/2018 USD, purchaser price
# 3  kg CO2e/2018 USD, purchaser price
# 4       kg/2018 USD, purchaser price
#
#    Supply Chain Emission Factors without Margins  \
# 0  Supply Chain Emission Factors without Margins
# 1                                          0.023
# 2                                          0.002
# 3                                          0.004
# 4                                          0.184
#
#    Margins of Supply Chain Emission Factors  \
# 0                                     0.041
# 1                                     0.000
# 2                                     0.000
# 3                                     0.000
# 4                                     0.017
#
#    Supply Chain Emission Factors with Margins  Unnamed: 7  \
# 0                                       0.465         NaN
# 1                                       0.023         NaN
# 2                                       0.002         NaN
# 3                                       0.004         NaN
# 4                                       0.201         NaN
#
#    DQ ReliabilityScore of Factors without Margins  \
# 0                                               4
# 1                                               3
# 2                                               4
# 3                                               3
# 4                                               4
#
#    DQ TemporalCorrelation of Factors without Margins  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    DQ GeographicalCorrelation of Factors without Margins  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    DQ TechnologicalCorrelation of Factors without Margins  \
# 0                                                  4
# 1                                                  1
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    DQ DataCollection of Factors without Margins
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1

# %%
all_data = []

for year in years:
    try:
        # Corrected to use pd.read_csv for CSV files
        df_com = pd.read_csv(excel_file)
        df_ind = pd.read_csv(excel_file)

        df_com['Source'] = 'Commodity'
        df_ind['Source'] = 'Industry'
        df_com['Year'] = df_ind['Year'] = year

        df_com.columns = df_com.columns.str.strip()
        df_ind.columns = df_ind.columns.str.strip()

        df_com.rename(columns={
            'Commodity Code': 'Code',
            'Commodity Name': 'Name'
        }, inplace=True)

        df_ind.rename(columns={
            'Industry Code': 'Code',
            'Industry Name': 'Name'
        }, inplace=True)

        all_data.append(pd.concat([df_com, df_ind], ignore_index=True))

    except Exception as e:
        print(f"Error processing year {year}: {e}")

# %%
df = pd.concat(all_data, ignore_index=True)
df.head()
# Out:
#   Industry Code                              Industry Name       Substance  \
# 0         111CA                                      Farms  carbon dioxide
# 1         111CA                                      Farms         methane
# 2         111CA                                      Farms   nitrous oxide
# 3         111CA                                      Farms      other GHGs
# 4         113FF  Forestry, fishing, and related activities  carbon dioxide
#
#                                 Unit  \
# 0       kg/2018 USD, purchaser price
# 1       kg/2018 USD, purchaser price
# 2       kg/2018 USD, purchaser price
# 3  kg CO2e/2018 USD, purchaser price
# 4       kg/2018 USD, purchaser price
#
#    Supply Chain Emission Factors without Margins  \
# 0  Supply Chain Emission Factors without Margins
# 1                                          0.023
# 2                                          0.002
# 3                                          0.004
# 4                                          0.184
#
#    Margins of Supply Chain Emission Factors  \
# 0                                     0.041
# 1                                     0.000
# 2                                     0.000
# 3                                     0.000
# 4                                     0.017
#
#    Supply Chain Emission Factors with Margins  Unnamed: 7  \
# 0                                       0.465         NaN
# 1                                       0.023         NaN
# 2                                       0.002         NaN
# 3                                       0.004         NaN
# 4                                       0.201         NaN
#
#    DQ ReliabilityScore of Factors without Margins  \
# 0                                               4
# 1                                               3
# 2                                               4
# 3                                               3
# 4                                               4
#
#    DQ TemporalCorrelation of Factors without Margins  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    DQ GeographicalCorrelation of Factors without Margins  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    DQ TechnologicalCorrelation of Factors without Margins  \
# 0                                                  4
# 1                                                  1
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    DQ DataCollection of Factors without Margins     Source  Year Code Name
# 0                                             1  Commodity  2010  NaN  NaN
# 1                                             1  Commodity  2010  NaN  NaN
# 2                                             1  Commodity  2010  NaN  NaN
# 3                                             1  Commodity  2010  NaN  NaN
# 4                                             1  Commodity  2010  NaN  NaN

# %% [markdown]
# Step 3: Data Preprocessing

# %%
df.columns
# Out:
# Index(['Industry Code', 'Industry Name', 'Substance', 'Unit',
#        'Supply Chain Emission Factors without Margins',
#        'Margins of Supply Chain Emission Factors',
#        'Supply Chain Emission Factors with Margins', 'Unnamed: 7',
#        'DQ ReliabilityScore of Factors without Margins',
#        'DQ TemporalCorrelation of Factors without Margins',
#        'DQ GeographicalCorrelation of Factors without Margins',
#        'DQ TechnologicalCorrelation of Factors without Margins',
#        'DQ DataCollection of Factors without Margins', 'Source', 'Year',
#        'Code', 'Name'],
#       dtype='object')

# %%
# As there is no data avaialble in Unnamed coulmn so we will drop the column
df.drop(columns=['Unnamed: 7'],inplace=True)

# %%
df.columns
# Out:
# Index(['Industry Code', 'Industry Name', 'Substance', 'Unit',
#        'Supply Chain Emission Factors without Margins',
#        'Margins of Supply Chain Emission Factors',
#        'Supply Chain Emission Factors with Margins',
#        'DQ ReliabilityScore of Factors without Margins',
#        'DQ TemporalCorrelation of Factors without Margins',
#        'DQ GeographicalCorrelation of Factors without Margins',
#        'DQ TechnologicalCorrelation of Factors without Margins',
#        'DQ DataCollection of Factors without Margins', 'Source', 'Year',
#        'Code', 'Name'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 16 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Industry Code                                           1848 non-null   object
#  1   Industry Name                                           1848 non-null   object
#  2   Substance                                               3696 non-null   object
#  3   Unit                                                    3696 non-null   object
#  4   Supply Chain Emission Factors without Margins           3696 non-null   object
#  5   Margins of Supply Chain Emission Factors                3696 non-null   float64
#  6   Supply Chain Emission Factors with Margins              3696 non-null   float64
#  7   DQ ReliabilityScore of Factors without Margins          3696 non-null   int64
#  8   DQ TemporalCorrelation of Factors without Margins       3696 non-null   int64
#  9   DQ GeographicalCorrelation of Factors without Margins   3696 non-null   int64
#  10  DQ TechnologicalCorrelation of Factors without Margins  3696 non-null   int64
#  11  DQ DataCollection of Factors without Margins            3696 non-null   int64
#  12  Source                                                  3696 non-null   object
#  13  Year                                                    3696 non-null   int64
#  14  Code                                                    1848 non-null   object
#  15  Name                                                    1848 non-null   object
# dtypes: float64(2), int64(6), object(8)
# memory usage: 462.1+ KB
# None

# %%
df.describe().T
# Out:
#                                                      count         mean  \
# Margins of Supply Chain Emission Factors            3696.0     0.002045
# Supply Chain Emission Factors with Margins          3696.0     0.081939
# DQ ReliabilityScore of Factors without Margins      3696.0     3.405303
# DQ TemporalCorrelation of Factors without Margins   3696.0     2.000000
# DQ GeographicalCorrelation of Factors without M...  3696.0     1.000000
# DQ TechnologicalCorrelation of Factors without ...  3696.0     2.810606
# DQ DataCollection of Factors without Margins        3696.0     1.000000
# Year                                                3696.0  2013.000000
#
#                                                          std     min     25%  \
# Margins of Supply Chain Emission Factors            0.007631     0.0     0.0
# Supply Chain Emission Factors with Margins          0.266327     0.0     0.0
# DQ ReliabilityScore of Factors without Margins      0.556146     2.0     3.0
# DQ TemporalCorrelation of Factors without Margins   0.000000     2.0     2.0
# DQ GeographicalCorrelation of Factors without M...  0.000000     1.0     1.0
# DQ TechnologicalCorrelation of Factors without ...  1.250215     1.0     1.0
# DQ DataCollection of Factors without Margins        0.000000     1.0     1.0
# Year                                                2.000271  2010.0  2011.0
#
#                                                          50%         75%  \
# Margins of Supply Chain Emission Factors               0.000     0.00000
# Supply Chain Emission Factors with Margins             0.002     0.04075
# DQ ReliabilityScore of Factors without Margins         3.000     4.00000
# DQ TemporalCorrelation of Factors without Margins      2.000     2.00000
# DQ GeographicalCorrelation of Factors without M...     1.000     1.00000
# DQ TechnologicalCorrelation of Factors without ...     3.000     4.00000
# DQ DataCollection of Factors without Margins           1.000     1.00000
# Year                                                2013.000  2015.00000
#
#                                                          max
# Margins of Supply Chain Emission Factors               0.053
# Supply Chain Emission Factors with Margins             3.425
# DQ ReliabilityScore of Factors without Margins         4.000
# DQ TemporalCorrelation of Factors without Margins      2.000
# DQ GeographicalCorrelation of Factors without M...     1.000
# DQ TechnologicalCorrelation of Factors without ...     5.000
# DQ DataCollection of Factors without Margins           1.000
# Year                                                2016.000

# %%
df.isnull().sum()
# Out:
# Industry Code                                             1848
# Industry Name                                             1848
# Substance                                                    0
# Unit                                                         0
# Supply Chain Emission Factors without Margins                0
# Margins of Supply Chain Emission Factors                     0
# Supply Chain Emission Factors with Margins                   0
# DQ ReliabilityScore of Factors without Margins               0
# DQ TemporalCorrelation of Factors without Margins            0
# DQ GeographicalCorrelation of Factors without Margins        0
# DQ TechnologicalCorrelation of Factors without Margins       0
# DQ DataCollection of Factors without Margins                 0
# Source                                                       0
# Year                                                         0
# Code                                                      1848
# Name                                                      1848
# dtype: int64

# %%
# Visualize distribution
sns.histplot(df['Supply Chain Emission Factors with Margins'], bins=50)
plt.title('Target Variable Distribution')
plt.show()

# %%
# Check categorical variables
print(df['Substance'].value_counts())
# Out:
# Substance
# carbon dioxide    924
# methane           924
# nitrous oxide     924
# other GHGs        924
# Name: count, dtype: int64

# %%
print(df['Unit'].value_counts())
# Out:
# Unit
# kg/2018 USD, purchaser price         2772
# kg CO2e/2018 USD, purchaser price     924
# Name: count, dtype: int64

# %%
print(df['Source'].value_counts())
# Out:
# Source
# Commodity    1848
# Industry     1848
# Name: count, dtype: int64

# %%
df['Substance'].unique()
# Out:
# array(['carbon dioxide', 'methane', 'nitrous oxide', 'other GHGs'],
#       dtype=object)

# %%
substance_map={'carbon dioxide':0, 'methane':1, 'nitrous oxide':2, 'other GHGs':3}

# %%
df['Substance']=df['Substance'].map(substance_map)

# %%
df['Substance'].unique()
# Out:
# array([0, 1, 2, 3])

# %%
print(df['Unit'].unique())
# Out:
# ['kg/2018 USD, purchaser price' 'kg CO2e/2018 USD, purchaser price']

# %%
unit_map={'kg/2018 USD, purchaser price':0, 'kg CO2e/2018 USD, purchaser price':1}

# %%
df['Unit']=df['Unit'].map(unit_map)

# %%
print(df['Unit'].unique())
# Out:
# [0 1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 16 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Industry Code                                           1848 non-null   object
#  1   Industry Name                                           1848 non-null   object
#  2   Substance                                               3696 non-null   int64
#  3   Unit                                                    3696 non-null   int64
#  4   Supply Chain Emission Factors without Margins           3696 non-null   object
#  5   Margins of Supply Chain Emission Factors                3696 non-null   float64
#  6   Supply Chain Emission Factors with Margins              3696 non-null   float64
#  7   DQ ReliabilityScore of Factors without Margins          3696 non-null   int64
#  8   DQ TemporalCorrelation of Factors without Margins       3696 non-null   int64
#  9   DQ GeographicalCorrelation of Factors without Margins   3696 non-null   int64
#  10  DQ TechnologicalCorrelation of Factors without Margins  3696 non-null   int64
#  11  DQ DataCollection of Factors without Margins            3696 non-null   int64
#  12  Source                                                  3696 non-null   object
#  13  Year                                                    3696 non-null   int64
#  14  Code                                                    1848 non-null   object
#  15  Name                                                    1848 non-null   object
# dtypes: float64(2), int64(8), object(6)
# memory usage: 462.1+ KB

# %%
df.Code.unique()
# Out:
# array([nan, '111CA', '113FF', '211', '212', '213', '22', '23', '311FT',
#        '313TT', '315AL', '321', '322', '323', '324', '325', '326', '327',
#        '331', '332', '333', '334', '335', '3361MV', '3364OT', '337',
#        '339', '42', '441', '445', '452', '481', '482', '483', '484',
#        '485', '486', '487OS', '493', '4A0', '511', '512', '513', '514',
#        '521CI', '523', '524', '525', '532RL', '5411', '5412OP', '5415',
#        '55', '561', '562', '61', '621', '622', '623', '624', '711AS',
#        '713', '721', '722', '81', 'HS', 'ORE'], dtype=object)

# %%
df.Name.unique()
# Out:
# array([nan, 'Farms', 'Forestry, fishing, and related activities',
#        'Oil and gas extraction', 'Mining, except oil and gas',
#        'Support activities for mining', 'Utilities', 'Construction',
#        'Food and beverage and tobacco products',
#        'Textile mills and textile product mills',
#        'Apparel and leather and allied products', 'Wood products',
#        'Paper products', 'Printing and related support activities',
#        'Petroleum and coal products', 'Chemical products',
#        'Plastics and rubber products', 'Nonmetallic mineral products',
#        'Primary metals', 'Fabricated metal products', 'Machinery',
#        'Computer and electronic products',
#        'Electrical equipment, appliances, and components',
#        'Motor vehicles, bodies and trailers, and parts',
#        'Other transportation equipment', 'Furniture and related products',
#        'Miscellaneous manufacturing', 'Wholesale trade',
#        'Motor vehicle and parts dealers', 'Food and beverage stores',
#        'General merchandise stores', 'Air transportation',
#        'Rail transportation', 'Water transportation',
#        'Truck transportation',
#        'Transit and ground passenger transportation',
#        'Pipeline transportation',
#        'Other transportation and support activities',
#        'Warehousing and storage', 'Other retail',
#        'Publishing industries, except internet (includes software)',
#        'Motion picture and sound recording industries',
#        'Broadcasting and telecommunications',
#        'Data processing, internet publishing, and other information services',
#        'Federal Reserve banks, credit intermediation, and related activities',
#        'Securities, commodity contracts, and investments',
#        'Insurance carriers and related activities',
#        'Funds, trusts, and other financial vehicles',
#        'Rental and leasing services and lessors of intangible assets',
#        'Legal services',
#        'Miscellaneous professional, scientific, and technical services',
#        'Computer systems design and related services',
#        'Management of companies and enterprises',
#        'Administrative and support services',
#        'Waste management and remediation services',
#        'Educational services', 'Ambulatory health care services',
#        'Hospitals', 'Nursing and residential care facilities',
#        'Social assistance',
#        'Performing arts, spectator sports, museums, and related activities',
#        'Amusements, gambling, and recreation industries', 'Accommodation',
#        'Food services and drinking places',
#        'Other services, except government', 'Housing',
#        'Other real estate'], dtype=object)

# %%
len(df.Name.unique())
# Out:
# 67

# %%
# Drop non-numeric columns not needed,
# Alos drop Code and Year columns since there is no need of both of the columns
df.drop(columns=['Name','Code','Year'], inplace=True)

# %%
# len(df.Code.unique())

# %%
df.shape
# Out:
# (3696, 13)

# %%
# Define features and target
X = df.drop(columns=['Supply Chain Emission Factors with Margins'])
y = df['Supply Chain Emission Factors with Margins']

# %%
plt.figure(figsize=(6, 3))
sns.countplot(x=df["Substance"])
plt.title("Count Plot: Substance")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 3))
sns.countplot(x=df["Unit"])
plt.title("Count Plot: Unit")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x=df["Source"])
plt.title("Count Plot: Source (Industry vs Commodity)")
plt.tight_layout()
plt.show()

# %%
df.select_dtypes(include=np.number).corr()
# Out:
#                                                     Substance      Unit  \
# Substance                                            1.000000  0.774597
# Unit                                                 0.774597  1.000000
# Margins of Supply Chain Emission Factors            -0.358357 -0.154785
# Supply Chain Emission Factors with Margins          -0.391687 -0.162149
# DQ ReliabilityScore of Factors without Margins       0.374702  0.255634
# DQ TemporalCorrelation of Factors without Margins         NaN       NaN
# DQ GeographicalCorrelation of Factors without M...        NaN       NaN
# DQ TechnologicalCorrelation of Factors without ...   0.447197  0.556335
# DQ DataCollection of Factors without Margins              NaN       NaN
#
#                                                     Margins of Supply Chain Emission Factors  \
# Substance                                                                          -0.358357
# Unit                                                                               -0.154785
# Margins of Supply Chain Emission Factors                                            1.000000
# Supply Chain Emission Factors with Margins                                          0.294207
# DQ ReliabilityScore of Factors without Margins                                     -0.088268
# DQ TemporalCorrelation of Factors without Margins                                        NaN
# DQ GeographicalCorrelation of Factors without M...                                       NaN
# DQ TechnologicalCorrelation of Factors without ...                                  0.109329
# DQ DataCollection of Factors without Margins                                             NaN
#
#                                                     Supply Chain Emission Factors with Margins  \
# Substance                                                                            -0.391687
# Unit                                                                                 -0.162149
# Margins of Supply Chain Emission Factors                                              0.294207
# Supply Chain Emission Factors with Margins                                            1.000000
# DQ ReliabilityScore of Factors without Margins                                       -0.161862
# DQ TemporalCorrelation of Factors without Margins                                          NaN
# DQ GeographicalCorrelation of Factors without M...                                         NaN
# DQ TechnologicalCorrelation of Factors without ...                                    0.019640
# DQ DataCollection of Factors without Margins                                               NaN
#
#                                                     DQ ReliabilityScore of Factors without Margins  \
# Substance                                                                                 0.374702
# Unit                                                                                      0.255634
# Margins of Supply Chain Emission Factors                                                 -0.088268
# Supply Chain Emission Factors with Margins                                               -0.161862
# DQ ReliabilityScore of Factors without Margins                                            1.000000
# DQ TemporalCorrelation of Factors without Margins                                              NaN
# DQ GeographicalCorrelation of Factors without M...                                             NaN
# DQ TechnologicalCorrelation of Factors without ...                                        0.344750
# DQ DataCollection of Factors without Margins                                                   NaN
#
#                                                     DQ TemporalCorrelation of Factors without Margins  \
# Substance                                                                                         NaN
# Unit                                                                                              NaN
# Margins of Supply Chain Emission Factors                                                          NaN
# Supply Chain Emission Factors with Margins                                                        NaN
# DQ ReliabilityScore of Factors without Margins                                                    NaN
# DQ TemporalCorrelation of Factors without Margins                                                 NaN
# DQ GeographicalCorrelation of Factors without M...                                                NaN
# DQ TechnologicalCorrelation of Factors without ...                                                NaN
# DQ DataCollection of Factors without Margins                                                      NaN
#
#                                                     DQ GeographicalCorrelation of Factors without Margins  \
# Substance                                                                                         NaN
# Unit                                                                                              NaN
# Margins of Supply Chain Emission Factors                                                          NaN
# Supply Chain Emission Factors with Margins                                                        NaN
# DQ ReliabilityScore of Factors without Margins                                                    NaN
# DQ TemporalCorrelation of Factors without Margins                                                 NaN
# DQ GeographicalCorrelation of Factors without M...                                                NaN
# DQ TechnologicalCorrelation of Factors without ...                                                NaN
# DQ DataCollection of Factors without Margins                                                      NaN
#
#                                                     DQ TechnologicalCorrelation of Factors without Margins  \
# Substance                                                                                    0.447197
# Unit                                                                                         0.556335
# Margins of Supply Chain Emission Factors                                                     0.109329
# Supply Chain Emission Factors with Margins                                                   0.019640
# DQ ReliabilityScore of Factors without Margins                                               0.344750
# DQ TemporalCorrelation of Factors without Margins                                                 NaN
# DQ GeographicalCorrelation of Factors without M...                                                NaN
# DQ TechnologicalCorrelation of Factors without ...                                           1.000000
# DQ DataCollection of Factors without Margins                                                      NaN
#
#                                                     DQ DataCollection of Factors without Margins
# Substance                                                                                    NaN
# Unit                                                                                         NaN
# Margins of Supply Chain Emission Factors                                                     NaN
# Supply Chain Emission Factors with Margins                                                   NaN
# DQ ReliabilityScore of Factors without Margins                                               NaN
# DQ TemporalCorrelation of Factors without Margins                                            NaN
# DQ GeographicalCorrelation of Factors without M...                                           NaN
# DQ TechnologicalCorrelation of Factors without ...                                           NaN
# DQ DataCollection of Factors without Margins                                                 NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 13 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Industry Code                                           1848 non-null   object
#  1   Industry Name                                           1848 non-null   object
#  2   Substance                                               3696 non-null   int64
#  3   Unit                                                    3696 non-null   int64
#  4   Supply Chain Emission Factors without Margins           3696 non-null   object
#  5   Margins of Supply Chain Emission Factors                3696 non-null   float64
#  6   Supply Chain Emission Factors with Margins              3696 non-null   float64
#  7   DQ ReliabilityScore of Factors without Margins          3696 non-null   int64
#  8   DQ TemporalCorrelation of Factors without Margins       3696 non-null   int64
#  9   DQ GeographicalCorrelation of Factors without Margins   3696 non-null   int64
#  10  DQ TechnologicalCorrelation of Factors without Margins  3696 non-null   int64
#  11  DQ DataCollection of Factors without Margins            3696 non-null   int64
#  12  Source                                                  3696 non-null   object
# dtypes: float64(2), int64(7), object(4)
# memory usage: 375.5+ KB

# %%
# Correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Normalize features

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(pd.get_dummies(X))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = RandomForestRegressor(random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(X_test)
# r2_sccore approx 1 gives us perfecr model

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f'RMSE: {rmse}')
print(f'R² Score: {r2}')
# Out:
# RMSE: 0.0003531452640856553
# R² Score: 0.9999979928298839

# %% [markdown]
# Hyperparameter Tuning

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5]
}

grid_search = GridSearchCV(RandomForestRegressor(random_state=42), param_grid, cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)

best_model = grid_search.best_estimator_
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}

# %% [markdown]
# Use best parameters for prediction

# %%
y_pred_best = best_model.predict(X_test)

print("Final RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_best)))
print("Final R²:", r2_score(y_test, y_pred_best))
# Out:
# Final RMSE: 0.0003531452640856553
# Final R²: 0.9999979928298839

# %% [markdown]
# Save model and encoders

# %%
# !mkdir models
# Out:
# mkdir: cannot create directory ‘models’: File exists

# %%
# Save model and encoders
joblib.dump(best_model, 'models/final_model.pkl')
joblib.dump(scaler, 'models/scaler.pkl')
# Out:
# ['models/scaler.pkl']

# %%
X.columns
# Out:
# Index(['Industry Code', 'Industry Name', 'Substance', 'Unit',
#        'Supply Chain Emission Factors without Margins',
#        'Margins of Supply Chain Emission Factors',
#        'DQ ReliabilityScore of Factors without Margins',
#        'DQ TemporalCorrelation of Factors without Margins',
#        'DQ GeographicalCorrelation of Factors without Margins',
#        'DQ TechnologicalCorrelation of Factors without Margins',
#        'DQ DataCollection of Factors without Margins', 'Source'],
#       dtype='object')
